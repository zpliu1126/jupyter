# %%
### 在对转录本的ORF进行预测后；比较每种ORF中两种转录本的数目

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np




###
fig,ax=plt.subplots()
labels=['in-frame change','frameshift','unchange ORF','Other']
Annotion=[0.4625,0.428,0.858,0.208]    ###算Annotion/unAnnotion的百分比
unAnnotion=[0.5375,0.572,0.142,0.792]

unrecongnized_FLNC=np.true_divide(unrecongnized_FLNC,total)
with plt.style.context('ggplot'):
    ax.bar(labels,Annotion,
           label="Annotion",
           width=barwidth,
           color='#a2d5f2',
          )
    ax.bar(labels,unAnnotion,
           label="unAnnotion",
           bottom=Annotion,
           width=barwidth,
           color='#ff7e67',
          )
          
###隐藏坐标轴
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel('Precentage of isoform',size='15')
##设置坐标轴字体大小
ax.set_xticklabels(labels,  
        fontdict={
        'size':'15',
        'rotation':'25', ##旋转45度
    })
ax.legend(loc="center",bbox_to_anchor=(0.5,1.05),ncol=4,fontsize='10') ##修改图例
fig.savefig('/public/home/zpliu/work/Alternative/result/Gh_result/CO31_32_result/ORF/Annotion_vs_un_annotion_frameshift.png', dpi=150, bbox_inches="tight")

##########################
###early stop
fig,ax=plt.subplots()
'''
ORFC: 'unchange stop with ORF change',
BC:'both stop codan and ORF change'
'''
labels=['ORFC','early','late','BC','Other']
Annotion=[0.4260,0.448,0.5948,0.8581,0.2077]    ###算Annotion/unAnnotion的百分比
unAnnotion=[0.574,0.552,0.406,0.142,0.793]

unrecongnized_FLNC=np.true_divide(unrecongnized_FLNC,total)
with plt.style.context('ggplot'):
    ax.bar(labels,Annotion,
           label="Annotion",
           width=barwidth,
           color='#a2d5f2',
          )
    ax.bar(labels,unAnnotion,
           label="unAnnotion",
           bottom=Annotion,
           width=barwidth,
           color='#ff7e67',
          )
          
###隐藏坐标轴
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel('Precentage of isoform',size='15')
##设置坐标轴字体大小
ax.set_xticklabels(labels,  
        fontdict={
        'size':'15',
        'rotation':'10', ##旋转45度
    })
ax.legend(loc="center",bbox_to_anchor=(0.5,1.05),ncol=4,fontsize='10') ##修改图例
fig.savefig('/public/home/zpliu/work/Alternative/result/Gh_result/CO31_32_result/ORF/Annotion_vs_un_annotion_earlyStop.png', dpi=150, bbox_inches="tight")
